# %%
# %reload_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
pd.options.display.max_columns = 999
pd.options.display.max_rows = 1999
pd.options.display.max_colwidth = 100

import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot, offline
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

import requests

from os import listdir
import unicodedata

from paths import *
from scripts.manipulation import remove_acentos
from scripts.manipulation import normalize_cols
from scripts import scrap_data
from scripts import manipulation
from scripts import manipulation_sp

from scripts import io
from scripts import vis_graphs

from datetime import datetime
today = datetime.today().strftime('%Y-%m-%d')

import yaml

# %% [markdown]
# Boletim SP
#
# https://www.seade.gov.br/coronavirus/?utm_source=portal&utm_medium=banner&utm_campaign=boletim-completo

# %% [markdown]
# ## Casos

# %%
casos_full = pd.read_csv('https://raw.githubusercontent.com/seade-R/dados-covid-sp/master/data/dados_covid_sp.csv', sep=';')
casos, sp_casos = manipulation_sp.padronize_casos(casos_full)

# %% [markdown]
# ## Internacoes

# %%
internacoes_full = pd.read_csv('https://github.com/seade-R/dados-covid-sp/raw/master/data/plano_sp_leitos_internacoes.csv', sep=';')
internacoes, sp_internacoes = manipulation_sp.padronize_internacoes(internacoes_full)

# %% [markdown]
# ## Ocupacao UTI

# %%
uti = pd.read_csv('../data/sp_gov/uti_ocupacao.csv', sep=';')

uti_final = uti.copy()


# mask =  uti_final['datahora'] == max(uti_final['datahora'])

# uti_final = uti_final[mask]

# uti_final['datahora'] = max(df_final['datahora'])

# %% [markdown]
# ## Add Fases

# %%
#merge all tables
df = manipulation_sp.padronize_planosp(sp_casos,sp_internacoes, uti_final)

# calculate fases
df = manipulation_sp.add_fases(df)

#padronize names and column names
df = manipulation_sp.padronize_planosp_names(df)

# %% [markdown]
# ## Colored Table

# %%
mask = df['Data']==max(df['Data'])
pd.options.display.float_format = '{:,.2f}'.format

df[mask].style.applymap(manipulation_sp.cases_color, subset=pd.IndexSlice[:, ['Capacidade Hospitalar','Evolução da Pandemia','Classif. Final']] )
# Out:
# <style  type="text/css" >
#     #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col5 {
#             background-color:  yellow;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col9 {
#             background-color:  yellow;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row1_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row1_col5 {
#             background-color:  yellow;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row1_col9 {
#             background-color:  yellow;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row2_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row2_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row2_col9 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row3_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row3_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row3_col9 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row4_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row4_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row4_col9 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row5_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row5_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row5_col9 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row6_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row6_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row6_col9 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row7_col2 {
#             background-color:  red;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row7_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row7_col9 {
#             background-color:  red;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row8_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row8_col5 {
#             background-color:  yellow;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row8_col9 {
#             background-color:  yellow;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row9_col2 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row9_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row9_col9 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row10_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row10_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row10_col9 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row11_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row11_col5 {
#             background-color:  red;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row11_col9 {
#             background-color:  red;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row12_col2 {
#             background-color:  red;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row12_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row12_col9 {
#             background-color:  red;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row13_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row13_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row13_col9 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row14_col2 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row14_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row14_col9 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row15_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row15_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row15_col9 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row16_col2 {
#             background-color:  green;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row16_col5 {
#             background-color:  orange;
#         }    #T_33fbeb62_d67e_11ea_a738_b337d6389ab0row16_col9 {
#             background-color:  orange;
#         }</style><table id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Data</th>        <th class="col_heading level0 col1" >DRS</th>        <th class="col_heading level0 col2" >Capacidade Hospitalar</th>        <th class="col_heading level0 col3" >Ocupação leitos UTI COVID</th>        <th class="col_heading level0 col4" >Leitos COVID/100 mil hab</th>        <th class="col_heading level0 col5" >Evolução da Pandemia</th>        <th class="col_heading level0 col6" >Variação de casos</th>        <th class="col_heading level0 col7" >Variação internações</th>        <th class="col_heading level0 col8" >Variação de óbitos</th>        <th class="col_heading level0 col9" >Classif. Final</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0level0_row0" class="row_heading level0 row0" >35</th>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col0" class="data row0 col0" >2020-07-30</td>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col1" class="data row0 col1" >DRS 01 - Município de São Paulo</td>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col2" class="data row0 col2" >4.0</td>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col3" class="data row0 col3" >64.1</td>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col4" class="data row0 col4" >30.47</td>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col5" class="data row0 col5" >3.0</td>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col6" class="data row0 col6" >1.74</td>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col7" class="data row0 col7" >0.97</td>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col8" class="data row0 col8" >0.73</td>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row0_col9" class="data row0 col9" >3.0</td>
#             </tr>
#             <tr>
#                         <th id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0level0_row1" class="row_heading level0 row1" >7</th>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row1_col0" class="data row1 col0" >2020-07-30</td>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row1_col1" class="data row1 col1" >DRS 02 - Araçatuba</td>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row1_col2" class="data row1 col2" >4.0</td>
#                         <td id="T_33fbeb62_d67e_11ea_a738_b337d6389ab0row1_col

# %% [markdown]
# ## Indicadores Comparacoes

# %%
from scripts import io

# get casos e internacoes
casos, sp_casos = manipulation_sp.padronize_casos(casos_full)
internacoes, sp_internacoes = manipulation_sp.padronize_internacoes(internacoes)

#get plano sp fases by region
planosp = io.read_sheets('Plano SP','df')
planosp['date'] = pd.to_datetime(planosp['date'], format="%d/%m/%Y")
colors = {"1":"red","2":"orange","3":"yellow","4":"green"}
planosp['fase'] = planosp['fase'].map(colors)
colors = {"parcial":"grey","final":"black"}
planosp['att'] = planosp['att'].map(colors)


final = manipulation_sp.padronize_planosp_parameters(sp_casos,sp_internacoes)

# %%
def get_figure(final,DRSs,var,title,planosp):
    
    data = []
    for drs in DRSs:
        dd = final[final['nome_drs']==drs]
        
        trace = go.Scatter(
                name=f'{drs}',
                x=dd['datahora'], 
                y=dd[var],
                mode='lines'
            )
        
        data.append(trace)
        
        y_min.append(dd[var].min())
        y_max.append(dd[var].max)
        
    layout =  go.Layout(height=720,barmode='group')

    fig = go.Figure(data=data, layout=layout)
    
    lw=2
    
    planosp_filter = planosp[planosp['drs'].isin([drs])]
    for (date,color) in zip(planosp_filter['date'],planosp_filter['att']):
#         print(color)
        fig.add_shape(
            # Line Horizontal
                type="line",
                x0=date,
                y0=min(y_min)*0.9,
                x1=date,
                y1=max(y_max)*1.1,
                line=dict(
                    color=color,
                    width=lw,
                    dash="dashdot",
                ),
        )

    fig.update_layout(title = title, hovermode= 'x unified',legend = go.layout.Legend(orientation='h'), xaxis_title='', yaxis_title=title, font = dict(size=16))
    
    return fig

# %%
DRSs = ['DRS 17 - Taubaté','DRS 04 - Baixada Santista','DRS 12 - Registro','DRS 01 - Município de São Paulo']
var = 'casos_14d_pc'
title = 'Casos 14d / 100mil'
get_figure(final,DRSs,var,title,planosp)

# %%
var = 'internacoes_14d_pc'
title = 'Internacoes 14d / 100mil'
get_figure(final,DRSs,var,title)

# %%
var = 'obitos_14d_pc'
title = 'Obitos 14d / 100mil'
get_figure(final,DRSs,var,title)

# %%
var = 'internacoes_var'
title = 'Variação de Internações'
get_figure(final,DRSs,var,title)

# %%
var = 'casos_var'
title = 'Variação de Casos'
get_figure(final,DRSs,var,title)

# %%
var = 'obitos_var'
title = 'Variação de Óbitos'
get_figure(final,DRSs,var,title)

# %%
fig = px.line(final[mask], x='datahora',y='leitos_pc', color='nome_drs', height=720)
fig.update_layout(hovermode= 'x unified',legend = go.layout.Legend(orientation='h'), xaxis_title='', font = dict(size=16))


# var = 'leitos_pc'
# title = 'Variação de Leitos'
# get_figure(final,mask,var,title)

# %% [markdown]
# ## Indicadores Unicos

# %%
def get_figure_bar(final,drs,var,var_mm,title,planosp):
    mask  = final['nome_drs'].isin([drs])
    final = final[mask]
    
    
    trace1 = go.Bar(
            name=f'{drs} - {title}',
            x=final['datahora'], 
            y=final[var],
        )
    if var_mm != '':
        trace2 = go.Scatter(
                name=f'{drs} - Média móvel 7 dias',
                x=final['datahora'], 
                y=final[var_mm],
                mode='lines+markers',
                line=dict(width=4, color='blue'),
            )

        data = [trace1,trace2]
    else:
        data = [trace1]

    
    layout =  go.Layout(height=720,barmode='group')
    
    fig = go.Figure(data=data, layout=layout)
    
    lw=2
    planosp_filter = planosp[planosp['drs'].isin([drs])]
    for (date,color) in zip(planosp_filter['date'],planosp_filter['fase']):
#         print(color)
        fig.add_shape(
            # Line Horizontal
                type="line",
                x0=date,
                y0=0,
                x1=date,
                y1=final[mask][var].max()*1.1,
                line=dict(
                    color=color,
                    width=lw,
                    dash="dashdot",
                ),
        )
    fig.update_layout(title = title, hovermode= 'x unified',legend = go.layout.Legend(orientation='h'), xaxis_title='', yaxis_title=title, font = dict(size=22))
    
    return fig

# %%
# drs = 'DRS 12 - Registro'
# drs = 'DRS 03 - Araraquara'
# drs = 'DRS 04 - Baixada Santista'
# drs = 'DRS 01 - Município de São Paulo'
drs = 'DRS 17 - Taubaté'



var = 'casos_novos'
var_mm = 'casos_mm7'  #'casos_mm7'
title = 'Novos Casos'





get_figure_bar(final,drs,var,var_mm,title,planosp)

# %%
var = 'obitos_novos'
var_mm = 'obitos_mm7'  #'casos_mm7'
title = 'Novos Óbitos'


get_figure_bar(final,drs,var,var_mm,title,planosp)

# %%
var = 'internacoes_7d'
var_mm = ''  #'casos_mm7'
title = 'Internaçoes ultimos 7 dias'

get_figure_bar(final,drs,var,var_mm,title,planosp)

# %%
pop = pd.read_csv('../../brasil_geodata/populacao/populacao_municipios_2001_to_2019.csv')
mask = (pop['ano'] == 2019) & (pop['uf']=='SP')
pop = pop[mask][['geocodigo','populacao']].rename(columns = {"populacao":"pop","geocodigo":"codigo_ibge"})

casos, sp_casos = manipulation_sp.padronize_casos(casos_full)

sp_casos = manipulation_sp.padronize_casos_sp(casos,pop,final)

# %%
var = 'obitos_pm'
title = 'Óbitos diarios por milhão'

# drs1 = 'DRS 12 - Registro'
drs2 = 'São José dos Campos'
drs3 = 'Taubaté'
drs4 = 'DRS 01 - Município de São Paulo'
drs5 = 'DRS 17 - Taubaté'

# mask  = ssp['nome_drs'].isin([drs1,drs2,drs3,drs4,drs5])
DRSs = [drs2,drs3,drs4,drs5]

get_figure(sp_casos,DRSs,var,title)

# %%
var = 'casos'
title = 'Casos'

get_figure(sp,mask,var,title)

# %%
var = 'obitos'
title = 'Óbitos'

get_figure(sp,mask,var,title)

# %%
def cases_color(val):
    
    for i in range(0,20,1):
        if val == str(i/10):
            color = 'red'
        else:
            pass
    for i in range(20,30,1):
        if val == str(i/10):
            color = 'orange'
        else:
            pass
    for i in range(30,40,1):
        if val == str(i/10):
            color = 'yellow'
        else:
            pass
    for i in range(40,50,1):
        if val == str(i/10):
            color = 'green'
        else:
            pass
        
    return 'background-color: %s' % color

# last_date = df['Data']==max(df['Data'])

# mask = (df['Data']==) | (df['Data']==)

mask = df['DRS'].isin(['DRS 17 - Taubaté'])

pd.options.display.float_format = '{:,.2f}'.format
df[mask].style.applymap(cases_color, subset=pd.IndexSlice[:, ['Capacidade Hospitalar','Evolução da Pandemia','Classif. Final']] )
# Out:
# <style  type="text/css" >
#     #T_61f54178_d366_11ea_a49f_918db887de51row0_col2 {
#             background-color:  green;
#         }    #T_61f54178_d366_11ea_a49f_918db887de51row0_col5 {
#             background-color:  orange;
#         }    #T_61f54178_d366_11ea_a49f_918db887de51row0_col9 {
#             background-color:  orange;
#         }    #T_61f54178_d366_11ea_a49f_918db887de51row1_col2 {
#             background-color:  green;
#         }    #T_61f54178_d366_11ea_a49f_918db887de51row1_col5 {
#             background-color:  orange;
#         }    #T_61f54178_d366_11ea_a49f_918db887de51row1_col9 {
#             background-color:  orange;
#         }    #T_61f54178_d366_11ea_a49f_918db887de51row2_col2 {
#             background-color:  green;
#         }    #T_61f54178_d366_11ea_a49f_918db887de51row2_col5 {
#             background-color:  orange;
#         }    #T_61f54178_d366_11ea_a49f_918db887de51row2_col9 {
#             background-color:  orange;
#         }    #T_61f54178_d366_11ea_a49f_918db887de51row3_col2 {
#             background-color:  green;
#         }    #T_61f54178_d366_11ea_a49f_918db887de51row3_col5 {
#             background-color:  orange;
#         }    #T_61f54178_d366_11ea_a49f_918db887de51row3_col9 {
#             background-color:  orange;
#         }</style><table id="T_61f54178_d366_11ea_a49f_918db887de51" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Data</th>        <th class="col_heading level0 col1" >DRS</th>        <th class="col_heading level0 col2" >Capacidade Hospitalar</th>        <th class="col_heading level0 col3" >Ocupação leitos UTI COVID</th>        <th class="col_heading level0 col4" >Leitos COVID/100 mil hab</th>        <th class="col_heading level0 col5" >Evolução da Pandemia</th>        <th class="col_heading level0 col6" >Variação de casos</th>        <th class="col_heading level0 col7" >Variação internações</th>        <th class="col_heading level0 col8" >Variação de óbitos</th>        <th class="col_heading level0 col9" >Classif. Final</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61f54178_d366_11ea_a49f_918db887de51level0_row0" class="row_heading level0 row0" >64</th>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row0_col0" class="data row0 col0" >2020-07-09</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row0_col1" class="data row0 col1" >DRS 17 - Taubaté</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row0_col2" class="data row0 col2" >4.0</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row0_col3" class="data row0 col3" >59.8</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row0_col4" class="data row0 col4" >14.88</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row0_col5" class="data row0 col5" >2.2</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row0_col6" class="data row0 col6" >1.0</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row0_col7" class="data row0 col7" >1.17</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row0_col8" class="data row0 col8" >1.28</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row0_col9" class="data row0 col9" >2.2</td>
#             </tr>
#             <tr>
#                         <th id="T_61f54178_d366_11ea_a49f_918db887de51level0_row1" class="row_heading level0 row1" >65</th>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row1_col0" class="data row1 col0" >2020-07-16</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row1_col1" class="data row1 col1" >DRS 17 - Taubaté</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row1_col2" class="data row1 col2" >4.0</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row1_col3" class="data row1 col3" >69.2</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row1_col4" class="data row1 col4" >15.27</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row1_col5" class="data row1 col5" >2.2</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row1_col6" class="data row1 col6" >1.13</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row1_col7" class="data row1 col7" >1.12</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row1_col8" class="data row1 col8" >1.54</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row1_col9" class="data row1 col9" >2.2</td>
#             </tr>
#             <tr>
#                         <th id="T_61f54178_d366_11ea_a49f_918db887de51level0_row2" class="row_heading level0 row2" >66</th>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row2_col0" class="data row2 col0" >2020-07-23</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row2_col1" class="data row2 col1" >DRS 17 - Taubaté</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row2_col2" class="data row2 col2" >4.0</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row2_col3" class="data row2 col3" >68.7</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row2_col4" class="data row2 col4" >15.85</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row2_col5" class="data row2 col5" >2.8</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row2_col6" class="data row2 col6" >1.23</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row2_col7" class="data row2 col7" >0.98</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row2_col8" class="data row2 col8" >1.2</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row2_col9" class="data row2 col9" >2.8</td>
#             </tr>
#             <tr>
#                         <th id="T_61f54178_d366_11ea_a49f_918db887de51level0_row3" class="row_heading level0 row3" >67</th>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row3_col0" class="data row3 col0" >2020-07-30</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row3_col1" class="data row3 col1" >DRS 17 - Taubaté</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row3_col2" class="data row3 col2" >4.0</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row3_col3" class="data row3 col3" >62.9</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row3_col4" class="data row3 col4" >17.28</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row3_col5" class="data row3 col5" >2.2</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row3_col6" class="data row3 col6" >1.67</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row3_col7" class="data row3 col7" >1.09</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row3_col8" class="data row3 col8" >1.05</td>
#                         <td id="T_61f54178_d366_11ea_a49f_918db887de51row3_col9" class="data row3 col9" >2.2</td>
#             </tr>
#     </tbody></table>
