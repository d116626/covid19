# %%
### WORLD POPULATION
# df_pop = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population')[0]
# cols = df_pop.loc[0].tolist()
# df_pop.columns = cols
# df_pop = df_pop.rename(columns={'Country (or dependent territory)':'countryname', 'Population':"population"})
# df_pop = df_pop[df_pop['population']!='Population']


# cols = ['countryname','population']
# df_pop = df_pop[cols]
# df_pop['countryname'] = df_pop['countryname'].apply(lambda x:x.split("[")[0]).str.replace('Brazil','Brasil')

# df_pop.to_csv('../data/world_population.csv', index=False)

# %%
# %reload_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

pd.options.display.max_colwidth = 100

import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot, offline
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

import requests

from os import listdir
import unicodedata

from paths import *
from tools.vizu import remove_acentos
from tools.vizu import normalize_cols
from tools.io import read_sheets


from datetime import datetime
today = datetime.today().strftime('%Y-%m-%d')

# %% [markdown]
# # Import Data

# %%
df = read_sheets('covid19_vale_do_paraiba')

# %%
### convert columns to numeric
for col in ['suspeitas','negativos','confirmados','recuperados']:
    df[col] = pd.to_numeric(df[col],errors='coerce')


#fill non values with NaN
df = df.replace('',np.nan)
df = df.sort_values(by='confirmados', ascending=False)

# %%
df
# Out:
#                   municipio  suspeitas  negativos  confirmados mortes  \
# 33      São José dos Campos      124.0        7.0         18.0    NaN
# 0                 Aparecida        4.0        3.0          2.0    NaN
# 36                  Taubaté      136.0       13.0          1.0    NaN
# 17                Lavrinhas        1.0        0.0          0.0    NaN
# 35            São Sebastião        2.0        0.0          0.0    NaN
# 31     São Bento do Sapucaí        0.0        0.0          0.0    NaN
# 30                Silveiras        1.0        0.0          0.0    NaN
# 29  Santo Antônio do Pinhal        0.0        0.0          0.0    NaN
# 28             Santa Branca        2.0        0.0          0.0    NaN
# 23                  Piquete        1.0        1.0          0.0    NaN
# 22          Pindamonhangaba       29.0        1.0          0.0    NaN
# 18                   Lorena       15.0        0.0          0.0    NaN
# 16                 Lagoinha        3.0        0.0          0.0    NaN
# 1                    Arapeí        0.0        0.0          0.0    NaN
# 14                  Jacareí       15.0        0.0          0.0    NaN
# 13                 Ilhabela       15.0        0.0          0.0    NaN
# 12                  Igaratá        2.0        0.0          0.0    NaN
# 11            Guaratinguetá       17.0        6.0          0.0    NaN
# 10                    Cunha        0.0        1.0          0.0    NaN
# 9                  Cruzeiro        4.0        0.0          0.0    NaN
# 8                  Caçapava       52.0        4.0          0.0      0
# 7             Caraguatatuba       41.0        3.0          0.0    NaN
# 5          Campos do Jordão       28.0        1.0          0.0    NaN
# 4        Cachoeira Paulista        2.0        0.0          0.0    NaN
# 38                  Ubatuba       34.0        0.0          0.0      0
# 2                    Areias        NaN        NaN          NaN    NaN
# 3                   Bananal        NaN        NaN          NaN    NaN
# 6                     Canas        NaN        NaN          NaN    NaN
# 15                 Jambeiro        NaN        NaN          NaN    NaN
# 19          Monteiro Lobato        NaN        NaN          NaN    NaN
# 20      Natividade da Serra        NaN        NaN          NaN    NaN
# 21                Paraibuna        NaN        NaN          NaN    NaN
# 24                    Potim        NaN        NaN          NaN    NaN
# 25                   Queluz        NaN        NaN          NaN    NaN
# 26        Redenção da Serra        NaN        NaN          NaN    NaN
# 27                  Roseira        NaN        NaN          NaN    NaN
# 32     São José do Barreiro        NaN        NaN          NaN    NaN
# 34   São Luiz do Paraitinga        NaN        NaN          NaN    NaN
# 37                 Tremembé        NaN        NaN          NaN    NaN
#
#     recuperados ultima_atualização  \
# 33          NaN         23/03/2020
# 0           NaN         24/03/2020
# 36          NaN         20/03/2020
# 17          NaN         20/03/2020
# 35          NaN         20/03/2020
# 31          NaN          12/3/2020
# 30          NaN         20/03/2020
# 29          NaN         20/03/2020
# 28          NaN         20/03/2020
